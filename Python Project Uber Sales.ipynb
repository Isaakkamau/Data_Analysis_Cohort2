# %%
#python final project

# %%
#Introduction to our project
#What the data is about
#This is an uber stock data at daily level from 10/5/2019 to 22/3/2022.
#The currency is in US dollars

# %%
#Import Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read the dataframe
df = pd.read_csv('C:/Users/USER/OneDrive/Documents/UBER.csv')
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2019-05-10  42.000000  45.000000  41.060001  41.570000  41.570000
# 1    2019-05-13  38.790001  39.240002  36.080002  37.099998  37.099998
# 2    2019-05-14  38.310001  39.959999  36.849998  39.959999  39.959999
# 3    2019-05-15  39.369999  41.880001  38.950001  41.290001  41.290001
# 4    2019-05-16  41.480000  44.060001  41.250000  43.000000  43.000000
# ..          ...        ...        ...        ...        ...        ...
# 720  2022-03-18  32.520000  33.419998  32.330002  33.360001  33.360001
# 721  2022-03-21  32.820000  32.820000  31.250000  31.980000  31.980000
# 722  2022-03-22  31.930000  33.599998  31.840000  33.349998  33.349998
# 723  2022-03-23  32.709999  33.680000  32.570000  33.060001  33.060001
# 724  2022-03-24  34.740002  34.950001  33.439999  34.700001  34.700001
#
#         Volume
# 0    186322500
# 1     79442400
# 2     46661100
# 3     36086100
# 4     38115500
# ..         ...
# ...

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2019-05-10  42.000000  45.000000  41.060001  41.570000  41.570000
# 1  2019-05-13  38.790001  39.240002  36.080002  37.099998  37.099998
# 2  2019-05-14  38.310001  39.959999  36.849998  39.959999  39.959999
# 3  2019-05-15  39.369999  41.880001  38.950001  41.290001  41.290001
# 4  2019-05-16  41.480000  44.060001  41.250000  43.000000  43.000000
#
#       Volume
# 0  186322500
# 1   79442400
# 2   46661100
# 3   36086100
# 4   38115500

# %%
df.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 720  2022-03-18  32.520000  33.419998  32.330002  33.360001  33.360001
# 721  2022-03-21  32.820000  32.820000  31.250000  31.980000  31.980000
# 722  2022-03-22  31.930000  33.599998  31.840000  33.349998  33.349998
# 723  2022-03-23  32.709999  33.680000  32.570000  33.060001  33.060001
# 724  2022-03-24  34.740002  34.950001  33.439999  34.700001  34.700001
#
#        Volume
# 720  35779700
# 721  35200600
# 722  21852800
# 723  19024700
# 724  52492200

# %%
df.shape
# Out:
# (725, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       725 non-null    object
#  1   Open       725 non-null    float64
#  2   High       725 non-null    float64
#  3   Low        725 non-null    float64
#  4   Close      725 non-null    float64
#  5   Adj Close  725 non-null    float64
#  6   Volume     725 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 39.8+ KB

# %%
df.isna().sum()
#Thus the data has no missing values
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  725.000000  725.000000  725.000000  725.000000  725.000000
# mean    40.166447   40.961435   39.261123   40.107255   40.107255
# std      9.198940    9.259164    9.075919    9.141862    9.141862
# min     15.960000   17.799999   13.710000   14.820000   14.820000
# 25%     32.730000   33.419998   31.983000   32.799999   32.799999
# 50%     39.000000   39.959999   38.009998   38.810001   38.810001
# 75%     46.700001   47.520000   45.860001   46.419998   46.419998
# max     63.250000   64.050003   60.799999   63.180000   63.180000
#
#              Volume
# count  7.250000e+02
# mean   2.472855e+07
# std    1.691406e+07
# min    3.380000e+06
# 25%    1.423060e+07
# 50%    2.079540e+07
# 75%    3.011960e+07
# max    1.863225e+08

# %%
df.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8548\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.996739  0.996635  0.992874   0.992874 -0.225505
# High       0.996739  1.000000  0.995986  0.996931   0.996931 -0.196218
# Low        0.996635  0.995986  1.000000  0.996646   0.996646 -0.246018
# Close      0.992874  0.996931  0.996646  1.000000   1.000000 -0.221111
# Adj Close  0.992874  0.996931  0.996646  1.000000   1.000000 -0.221111
# Volume    -0.225505 -0.196218 -0.246018 -0.221111  -0.221111  1.000000

# %%
df.duplicated().sum()
#The data has no duplicated values
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
file_path = 'C:/Users/USER/OneDrive/Documents/UBER.csv'
df = pd.read_csv(file_path)
df['Date']=pd.to_datetime(df['Date'])
plt.plot(df['Date'], df['Open'], color='red', label='Open')
plt.plot(df['Date'], df['Close'], color='yellow', label='Close')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Opening and Closing prices')
plt.xticks(rotation=75)
plt.legend()
plt.show()

# %%
plt.plot(df['Date'], df['High'], color='brown', label='High')
plt.plot(df['Date'], df['Low'], color='yellow', label='Low')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('High and Low Prices')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.plot(df['Date'], df['Volume'], color='purple')
plt.xlabel('Date')
plt.ylabel('Trading Volume')
plt.title('Trend in Stock Trading Volume')
plt.xticks(rotation=45)
plt.show()

# %%
#we can conclude our analyses by saying that the market is neutral, the open and close prices for each day are on the same level

# %%
#The high and low price fluctuations indicate an intraday volatility

# %%
#The higher trading volumes indicate increased market interest and activity in the sales
#It could also be that there are significant news or events in the uber market
#The higher trading volumes indicate better liquidity for the uber stock or could be that there are more buyers and sellers that are willing to trade 
#An increase in trading volume should provide more confidence in the uprend, otherwise the market should formulate new marketing strategies
